# %%
from langchain_ollama.chat_models import ChatOllama

model = ChatOllama(model="qwen3.5")

# %%
from langchain.tools import tool
from typing import Dict, Any
from langchain_community.tools import DuckDuckGoSearchRun

search = DuckDuckGoSearchRun()

@tool
def web_search(query: str) -> Dict[str, Any]:
    """Search the web for information"""
    return search.invoke(query)

# %%
system_prompt = """

You are a personal chef. The user will give you a list of ingredients they have left over in their house.

Using the web search tool, search the web for recipes that can be made with the ingredients they have.

Return recipe suggestions and eventually the recipe instructions to the user, if requested.

"""

# %%
from langchain.agents import create_agent
from langgraph.checkpoint.memory import InMemorySaver

agent = create_agent(
    model=model,
    tools=[web_search],
    system_prompt=system_prompt,
    checkpointer=InMemorySaver()
)

# %%
from langchain.messages import HumanMessage

config = {"configurable": {"thread_id": "1"}}

response = agent.invoke({"messages": [HumanMessage(content="I have some leftover chicken and rice. What can I make?")]}, config)

# %%
print(response['messages'][-1].content)
# Out:
# Based on your leftover chicken and rice, you can make several delicious and creative meals. Here are some great ideas:
#
# ### 1. **Fried Chicken and Rice (Fried Rice)**
#    - This is a quick and comforting meal using your leftover rice and chicken. Simply sauté your chicken and stir in the cooked rice with any preferred seasonings like soy sauce, garlic, and ginger.
#
# ### 2. **Chicken Rice Patties**
#    - Create patties by mixing the leftover chicken and rice with eggs and breadcrumbs, then fry or bake them until crispy. These can be served with dipping sauces or as part of a sandwich.
#
# ### 3. **Chicken and Rice Casserole**
#    - Combine chicken, rice, and a creamy base (like cream cheese or soup) with some cheese on top. Bake until golden and bubbly for a hearty, cheesy casserole that's perfect for using up leftovers.
#
# ### 4. **Leftover Chicken and Rice Waffles**
# ...

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content='I have some leftover chicken and rice. What can I make?', additional_kwargs={}, response_metadata={}, id='9f4d6b9f-61d0-4c97-9856-0f34697c7bec'),
#               AIMessage(content='', additional_kwargs={}, response_metadata={'model': 'qwen3.5', 'created_at': '2026-04-02T20:56:38.2820466Z', 'done': True, 'done_reason': 'stop', 'total_duration': 6186120900, 'load_duration': 5080224200, 'prompt_eval_count': 342, 'prompt_eval_duration': 140867300, 'eval_count': 81, 'eval_duration': 809717800, 'logprobs': None, 'model_name': 'qwen3.5', 'model_provider': 'ollama'}, id='lc_run--019d4ffb-c05c-74e0-926c-b2bc6066d257-0', tool_calls=[{'name': 'web_search', 'args': {'query': 'chicken and rice recipes for leftovers'}, 'id': '9599fd8c-58a0-4f04-bf36-3a1507f85990', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 342, 'output_tokens': 81, 'total_tokens': 423}),
# ...

# %% [markdown]
# # Adding langsmith to the existing project
#
# - create a py file and the agent code.
# - add the langgraph.json to the working directory.
# - for pip run `langrapg dev` and for uv run `uv run langgraph dev`
#   - if uv run fails, then
#     - `uv add "langgraph-cli[inmem]"`
#     - `uv run langgraph dev`
# - for temp and uvx `uvx --with "langgraph-cli[inmem]" langgraph dev`
