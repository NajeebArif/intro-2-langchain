# %% [markdown]
# ## Noo memory

# %%
from langchain_ollama.chat_models import ChatOllama

model = ChatOllama(model="qwen3.5")

# %%
from langchain.agents import create_agent

agent = create_agent(model=model)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content="Hello my name is Seán and my favourite colour is green")

response = agent.invoke({'messages': [question]})

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content='Hello my name is Seán and my favourite colour is green', additional_kwargs={}, response_metadata={}, id='ab6d939e-7a87-46ab-995b-c2ac26b44759'),
#               AIMessage(content='Hello Seán! It’s a pleasure to meet you.\n\nGreen is a wonderful favourite colour—such a vibrant and natural shade! How is your day going, and is there anything I can help you with?', additional_kwargs={}, response_metadata={'model': 'qwen3.5', 'created_at': '2026-04-02T20:07:22.8664004Z', 'done': True, 'done_reason': 'stop', 'total_duration': 22236408000, 'load_duration': 6099488000, 'prompt_eval_count': 22, 'prompt_eval_duration': 42301300, 'eval_count': 1501, 'eval_duration': 15120708600, 'logprobs': None, 'model_name': 'qwen3.5', 'model_provider': 'ollama'}, id='lc_run--019d4fce-68fd-7231-93ef-c6102863536e-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 22, 'output_tokens': 1501, 'total_tokens': 1523})]}

# %%
question = HumanMessage(content="What's my favourite colour?")

response = agent.invoke(
    {"messages": [question]} 
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's my favourite colour?", additional_kwargs={}, response_metadata={}, id='17a588d4-fdc4-494c-b318-280370f708ac'),
#               AIMessage(content="I don't actually know! 😅 I don't have access to your personal information or preferences unless you tell me.\n\nWould you like to share your favorite color? I'd be happy to hear it!", additional_kwargs={}, response_metadata={'model': 'qwen3.5', 'created_at': '2026-04-02T20:07:51.6312044Z', 'done': True, 'done_reason': 'stop', 'total_duration': 9583494000, 'load_duration': 129779900, 'prompt_eval_count': 16, 'prompt_eval_duration': 229723800, 'eval_count': 886, 'eval_duration': 8766935100, 'logprobs': None, 'model_name': 'qwen3.5', 'model_provider': 'ollama'}, id='lc_run--019d4fcf-0adf-7d02-a04b-cbdba65c76c1-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 16, 'output_tokens': 886, 'total_tokens': 902})]}

# %% [markdown]
# ## Memory

# %%
from langgraph.checkpoint.memory import InMemorySaver

agent = create_agent(model=model, checkpointer=InMemorySaver())

# %%
question = HumanMessage(content="Hello my name is Seán and my favourite colour is green")

config = {"configurable": {"thread_id": "1"}}

response = agent.invoke(
    {'messages': [question]},
    config
)

# %%
pprint(response)
# Out:
# {'messages': [HumanMessage(content='Hello my name is Seán and my favourite colour is green', additional_kwargs={}, response_metadata={}, id='7d9b3996-df9b-4169-97a6-ba391680f12b'),
#               AIMessage(content='Hello Seán! It’s a pleasure to meet you. 🟢 Green is such a lovely choice!\n\nHow is your day going so far? Is there anything you’d like to chat about or need help with today?', additional_kwargs={}, response_metadata={'model': 'qwen3.5', 'created_at': '2026-04-02T20:11:19.5408373Z', 'done': True, 'done_reason': 'stop', 'total_duration': 11277525800, 'load_duration': 169825800, 'prompt_eval_count': 22, 'prompt_eval_duration': 167719500, 'eval_count': 959, 'eval_duration': 10197954000, 'logprobs': None, 'model_name': 'qwen3.5', 'model_provider': 'ollama'}, id='lc_run--019d4fd2-3066-7080-a47b-8bb516345659-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 22, 'output_tokens': 959, 'total_tokens': 981})]}

# %%
question = HumanMessage(content="What's my favourite colour?")

response = agent.invoke(
    {"messages": [question]},
    config,  
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content='Hello my name is Seán and my favourite colour is green', additional_kwargs={}, response_metadata={}, id='7d9b3996-df9b-4169-97a6-ba391680f12b'),
#               AIMessage(content='Hello Seán! It’s a pleasure to meet you. 🟢 Green is such a lovely choice!\n\nHow is your day going so far? Is there anything you’d like to chat about or need help with today?', additional_kwargs={}, response_metadata={'model': 'qwen3.5', 'created_at': '2026-04-02T20:11:19.5408373Z', 'done': True, 'done_reason': 'stop', 'total_duration': 11277525800, 'load_duration': 169825800, 'prompt_eval_count': 22, 'prompt_eval_duration': 167719500, 'eval_count': 959, 'eval_duration': 10197954000, 'logprobs': None, 'model_name': 'qwen3.5', 'model_provider': 'ollama'}, id='lc_run--019d4fd2-3066-7080-a47b-8bb516345659-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 22, 'output_tokens': 959, 'total_tokens': 981}),
#               HumanMessage(content="What's my favourite colour?", additional_kwargs={}, response_metadata={}, id='55a3c6f9-ccfe-4c47-b225-9354e9e49fc4'),
#               AIMessage(content='Your favourite colour is **green**! 🟢', additional_kwargs={}, response_metadata={'model': 'qwen3.5', 'created_at': '2026-04-02T20:11:42.2232263Z', 'done': True, 'done_reason': 'stop', 'total_duration': 3460226400, 'load_duration': 123971200, 'prompt_eval_count': 84, 'prompt_eval_duration': 142128600, 'eval_count': 271, 'eval_duration': 3006232300, 'logprobs': None, 'model_name': 'qwen3.5', 'model_provider': 'ollama'}, id='lc_run--019d4fd2-a78a-7732-b929-2214c8ce8f28-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 84, 'output_tokens': 271, 'total_tokens': 355})]}
