# %% [markdown]
# # Text Input

# %%
from langchain_ollama.chat_models import ChatOllama

model = ChatOllama(
    model="qwen3.5"
)
# Out:
# d:\workspace\AI\langchain-academy\intro-2-langchain\.venv\Lib\site-packages\langchain_core\_api\deprecation.py:25: UserWarning: Core Pydantic V1 functionality isn't compatible with Python 3.14 or greater.
#   from pydantic.v1.fields import FieldInfo as FieldInfoV1

# %%
from langchain.agents import create_agent

agent = create_agent(
    model=model,
    system_prompt="You are a science fiction writer, create a capital city at the users request."
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content=[
    {"type": "text", "text": "What is the capital of the Moon?"}
])

response = agent.invoke(
    {"messages": [question]}
)

print(response['messages'][-1].content)
# Out:
# In the chronicles of the United Nations Lunar Authority, the capital is known as **Lunaris Prime**.
#
# Here is the dossier on our new seat of government:
#
# ### **Official Name:** Lunaris Prime
# **Designation:** The Apex
# **Coordinates:** Shackleton Crater (South Polar Region), Coordinates 86.15°S, 356.5°E
# **Population:** ~450,000 (residents of the inner rings) and 2 million (orbital docking population)
#
# ### **Geographic Structure**
# Lunaris Prime is not built *on* the ground, but rather *into* the regolith. The city is anchored within the deep floor of Shackleton Crater, a strategic choice for its unique "permanent twilight." Unlike equatorial sites that bathe in scorching sun or freezing shadows, the crater rim reflects sunlight off the inner walls, providing a consistent, low-level illumination that saves massive energy on artificial lighting.
#
# The city consists of three concentric rings:
# 1.  **The Inner Citadel:** The seat of the Lunar Council, containing the Executive Spire (a monolithic crystal tower) and the United Lunar Assembly. This area is heavily shielded with layers of processed regolith and lunar lava rock to deflect cosmic rays.
# 2.  **The Habitation Domes:** A series of pressurized geodesic structures where 90% of the population lives. These grow outward like silver mushrooms, anchored into the crater walls.
# 3.  **The Void Spire:** A massive orbital elevator dock located at the crater rim, allowing gravity-free transport to orbit, effectively connecting the lunar floor with deep space traffic.
#
# ### **Atmosphere & Environment**
# Inside Lunaris, gravity is simulated at 16% of Earth's standard (0.16 G) to protect the citizens from long-term atrophy, though the "Upper Rings" (where the Council sits) utilize a magnetic levitation floor to simulate 1 G for official proceedings. The artificial sky projects a "Blue Horizon"—a massive holographic simulation of the night sky from Earth's perspective—allowing citizens to look up and see the stars while under the constant gaze of the Sun on the opposite side of the moon.
#
# ### **Cultural Note**
# Because the city is built entirely of dark gray basalt and glass, the skyline is famously minimalist. There are no towering skyscrapers, only the gleaming white spires of the Council and the silver-domed residential clusters. The wind is rare; instead, the city is dominated by the hum of ventilation fans and the distant thrum of cargo ships docking at the Spire.
#
# Lunaris Prime stands not just as a city, but as the first human garden planted under a rock.

# %% [markdown]
# # Image Input

# %%
from ipywidgets import FileUpload
from IPython.display import display

uploader = FileUpload(accept='.png', multiple=False)
display(uploader)
# Out:
# FileUpload(value=(), accept='.png', description='Upload')

# %%
print(uploader.value)
# Out:
# ({'name': 'sci-fi-moon.png', 'type': 'image/png', 'size': 125948, 'content': <memory at 0x000002492F7F2B00>, 'last_modified': datetime.datetime(2026, 4, 2, 20, 23, 50, 446000, tzinfo=datetime.timezone.utc)},)

# %%
import base64

# Get the first (and only) uploaded file dict
uploaded_file = uploader.value[0]

# This is a memoryview
content_mv = uploaded_file["content"]

# Convert memoryview -> bytes
img_bytes = bytes(content_mv)  # or content_mv.tobytes()

# Now base64 encode
img_b64 = base64.b64encode(img_bytes).decode("utf-8")

# %%
multimodal_question = HumanMessage(content=[
    {"type": "text", "text": "Tell me about this capital"},
    {"type": "image", "base64": img_b64, "mime_type": "image/png"}
])

response = agent.invoke({'messages': [multimodal_question]})

print(response['messages'][-1].content)
# Out:
# Based on the ethereal and cosmic landscape depicted in your image, here is a profile of the capital city that inhabits this world.
#
# ### **Name: Oculis Prime (The City of the Eternal Eye)**
#
# **Overview:**
# Oculis Prime is the capital of the interstellar colony world, **Veridia**. It is not built *in* a city in the traditional sense, but rather is a sprawling coastal metropolis built along the jagged basalt cliffs that line a vast, dark ocean. It is a city dedicated entirely to the observation and worship of the "Great Spiral" above.
#
# **The Sky: The Great Spiral**
# The defining feature of Oculis Prime is the colossal celestial body dominating the horizon. It is likely a captured moon or a massive satellite that acts as a window into a distant, dying galaxy.
# *   **The Visual:** To the inhabitants, the sky is never truly black; it is filled with the swirling, glowing dust lanes and star clusters of the Great Spiral. The red and purple hues suggest a high-gravity environment where dust from the galactic core is constantly raining down.
# *   **Atmosphere:** The sky is perpetually twilight. The clouds are thick and violet, scattering the light of the distant stars, creating a perpetual, mystical "blue hour."
#
# **The Landscape & Flora:**
# *   **The Coast:** The city overlooks an endless sea that seems to reflect the purple light of the sky. The water is calm, suggesting high atmospheric pressure or a slow-moving current.
# *   **The Spires:** In the background, jagged rock formations rise vertically from the water—likely ancient volcanic vents or geological pillars. The city’s architecture mimics these natural spires, with towers built into the cliffs to get a clearer view of the sky.
# *   **Bioluminescence:** As seen in the foreground, the local flora has adapted to low-light conditions. Gardens of glowing, crystalline flora line the promenade, emitting a soft, soft-blue light that complements the cosmic backdrop.
#
# **Architecture & Lifestyle:**
# *   **The Observatory Quarter:** The tallest structures in the capital are not residential, but massive observatory domes. They are designed to track the movement of the Great Spiral and the other smaller moons visible in the distance (the blue moon to the left and the small dark orb).
# *   **Culture:** The people of Oculis Prime are astronomers and philosophers. They believe their world is a "seed" drifting through the galaxy, and the Great Spiral above is their ancestor or guardian.
# *   **Defense:** Because the sky is so crowded with other planetary bodies and moons, the city is likely heavily fortified against debris and rogue asteroids that are pulled by the gravity of the Great Spiral.
#
# In short, Oculis Prime is a place of profound solitude and wonder, where the citizens live in the shadow of a galaxy, listening to the hum of the universe from the edge of their ocean.
